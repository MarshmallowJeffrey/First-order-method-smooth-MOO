# %%
from experiments import experiment_mlp_plateau_comparison

# %%
cases = [
    dict(K=5, p=5, n=25, h=2, max_grad_evals=10_000,
         adaptive_eval_every_n_grads=1000),

    dict(K=6, p=6, n=30, h=2, max_grad_evals=18_000,
         adaptive_eval_every_n_grads=1500),

    dict(K=7, p=7, n=35, h=2, max_grad_evals=32_000,
         adaptive_eval_every_n_grads=2800),

    dict(K=8, p=8, n=40, h=2, max_grad_evals=50_000,
         adaptive_eval_every_n_grads=4000),
]

# %%
# 建议一次先运行一组
case = cases[3]

results = experiment_mlp_plateau_comparison(
    verbose=True,

    seed=10,
    init_seed=11,

    coarse_resolution=3,
    n_passes=1000,
    steps_per_point_per_pass=5,
    baseline_eval_every_n_grads=None,

    max_outer=5000,
    max_inner=20,
    lambda_max_starts=64,
    prune_inner=False,

    plateau_window=5,
    plateau_relative_improvement_tol=0.05,
    plateau_consecutive_windows=2,

    output_dir=(
        "/Users/shirch/vscode101/.venv/First-order-method-smooth-MOO/"
        "Adaptive Bundle Algorithm/output/plateau result/"
        f"K{case['K']}"
    ),

    **case,
)
# Out:
# ========================================================================
# Plateau comparison — baseline vs IPOPT adaptive
# ========================================================================
#   Shared problem: K=8, p=8, n=40, hidden_sizes=[2], backend=torch, d=42, max_grad_evals=50000, init_seed=11
#   Baseline pass 0/1000 | t=0.00s | iters=0 | grad_evals=0 | worst-case pc=3.7942e+01
#   Baseline pass 1/1000 | t=1.20s | iters=600 | grad_evals=4800 | worst-case pc=7.2912e-01
#   Baseline pass 2/1000 | t=2.25s | iters=1200 | grad_evals=9600 | worst-case pc=6.1857e-01
#   Baseline pass 3/1000 | t=3.36s | iters=1800 | grad_evals=14400 | worst-case pc=5.6903e-01
#   Baseline pass 4/1000 | t=4.45s | iters=2400 | grad_evals=19200 | worst-case pc=5.5813e-01
#   Baseline pass 5/1000 | t=5.44s | iters=3000 | grad_evals=24000 | worst-case pc=6.8178e-01
#   Baseline pass 6/1000 | t=6.34s | iters=3600 | grad_evals=28800 | worst-case pc=6.8290e-01
#   Baseline pass 7/1000 | t=7.34s | iters=4200 | grad_evals=33600 | worst-case pc=6.7855e-01
#   Baseline pass 8/1000 | t=8.35s | iters=4800 | grad_evals=38400 | worst-case pc=6.8508e-01
#   Baseline pass 9/1000 | t=9.31s | iters=5400 | grad_evals=43200 | worst-case pc=7.1972e-01
#   Baseline pass 10/1000 | t=10.26s | iters=6000 | grad_evals=48000 | worst-case pc=7.5349e-01
#   Baseline pass 11/1000 | t=10.64s | iters=6250 | grad_evals=50000 | worst-case pc=7.6585e-01
#   Adaptive outer 0/5000 | t=0.00s | bundle=1 | iters=0 | grad_evals=0 | worst-case pc=3.7942e+01
#   Adaptive outer 25/5000 | t=67.22s | bundle=501 | iters=500 | grad_evals=4000 | worst-case pc=9.1684e-01
#   Adaptive outer 50/5000 | t=183.33s | bundle=1001 | iters=1000 | grad_evals=8000 | worst-case pc=9.1684e-01
#   Adaptive outer 75/5000 | t=333.60s | bundle=1501 | iters=1500 | grad_evals=12000 | worst-case pc=9.1684e-01
#   Adaptive outer 100/5000 | t=537.25s | bundle=2001 | iters=2000 | grad_evals=16000 | worst-case pc=9.1684e-01
#   Adaptive outer 125/5000 | t=772.18s | bundle=2501 | iters=2500 | grad_evals=20000 | worst-case pc=9.1684e-01
#   Adaptive outer 150/5000 | t=1034.90s | bundle=3001 | iters=3000 | grad_evals=24000 | worst-case pc=9.1684e-01
#   Adaptive outer 175/5000 | t=1331.31s | bundle=3501 | iters=3500 | grad_evals=28000 | worst-case pc=9.1684e-01
#   Adaptive outer 200/5000 | t=1667.23s | bundle=4001 | iters=4000 | grad_evals=32000 | worst-case pc=9.1684e-01
#   Adaptive outer 225/5000 | t=2040.98s | bundle=4501 | iters=4500 | grad_evals=36000 | worst-case pc=9.1684e-01
#   Adaptive outer 250/5000 | t=2450.60s | bundle=5001 | iters=5000 | grad_evals=40000 | worst-case pc=9.1684e-01
#   Adaptive outer 275/5000 | t=2897.92s | bundle=5501 | iters=5500 | grad_evals=44000 | worst-case pc=9.1684e-01
#   Adaptive outer 300/5000 | t=3775.59s | bundle=6001 | iters=6000 | grad_evals=48000 | worst-case pc=9.1684e-01
#   Adaptive outer 313/5000 | t=4091.37s | bundle=6251 | iters=6250 | grad_evals=50000 | worst-case pc=9.1684e-01
#
# Plateau summary
#   Method            Found   Onset gradients   Onset CPU   Plateau GN*
#   Baseline          no                    -           -   -
#   IPOPT Adaptive    yes               4,000      67.22s   9.1684e-01

# %%
baseline = results["plateaus"]["baseline"]
adaptive = results["plateaus"]["ipopt_adaptive"]

print("Baseline:", baseline)
print("Adaptive:", adaptive)

if baseline["found"] and adaptive["found"]:
    ratio = baseline["plateau_level"] / adaptive["plateau_level"]
    print("Baseline / Adaptive =", ratio)
    print("目标现象成立:", ratio > 1.0)

print("Gradient-evaluation plot:",
      results["plots"]["baseline_vs_ipopt_gradient_evaluations"])
print("CPU-time plot:",
      results["plots"]["baseline_vs_ipopt_cpu_time"])
# Out:
# Baseline: {'found': False, 'onset_index': None, 'onset_grad_evals': None, 'onset_cpu_time': None, 'plateau_level': None}
# Adaptive: {'found': True, 'onset_index': 1, 'onset_grad_evals': 4000, 'onset_cpu_time': 67.22195315361023, 'plateau_level': 0.9168420911482901}
# Gradient-evaluation plot: /Users/shirch/vscode101/.venv/First-order-method-smooth-MOO/Adaptive Bundle Algorithm/output/plateau result/K8/baseline_vs_ipopt_gradient_evaluations_001.png
# CPU-time plot: /Users/shirch/vscode101/.venv/First-order-method-smooth-MOO/Adaptive Bundle Algorithm/output/plateau result/K8/baseline_vs_ipopt_cpu_time_001.png
