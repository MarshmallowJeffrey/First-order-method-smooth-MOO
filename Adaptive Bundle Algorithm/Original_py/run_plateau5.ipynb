# %%
from experiments import experiment_mlp_plateau_comparison

# %%
cases = [
    dict(K=5, p=5, n=25, h=2, max_grad_evals=10_000,
         adaptive_eval_every_n_grads=1000),

    dict(K=6, p=6, n=30, h=2, max_grad_evals=18_000,
         adaptive_eval_every_n_grads=1500),

    dict(K=7, p=7, n=35, h=2, max_grad_evals=32_000,
         adaptive_eval_every_n_grads=2800),

    dict(K=8, p=8, n=40, h=2, max_grad_evals=50_000,
         adaptive_eval_every_n_grads=4800),
]

# %%
# 建议一次先运行一组
case = cases[0]

results = experiment_mlp_plateau_comparison(
    verbose=True,

    seed=10,
    init_seed=11,

    coarse_resolution=3,
    n_passes=1000,
    steps_per_point_per_pass=5,
    baseline_eval_every_n_grads=None,

    max_outer=5000,
    max_inner=50,
    lambda_max_starts=20,
    prune_inner=False,

    plateau_window=5,
    plateau_relative_improvement_tol=0.05,
    plateau_consecutive_windows=2,

    output_dir=(
        "/Users/shirch/vscode101/.venv/First-order-method-smooth-MOO/"
        "Adaptive Bundle Algorithm/output/plateau result/"
        f"K{case['K']}"
    ),

    **case,
)
# Out:
# ========================================================================
# Plateau comparison — baseline vs IPOPT adaptive
# ========================================================================
#   Shared problem: K=5, p=5, n=25, h=2, d=27, max_grad_evals=10000, init_seed=11
#   Baseline pass 0/1000 | t=0.00s | iters=0 | grad_evals=0 | worst-case pc=6.0227e+00
#   Baseline pass 1/1000 | t=0.02s | iters=175 | grad_evals=875 | worst-case pc=3.2213e-01
#   Baseline pass 2/1000 | t=0.04s | iters=350 | grad_evals=1750 | worst-case pc=2.8263e-01
#   Baseline pass 3/1000 | t=0.06s | iters=525 | grad_evals=2625 | worst-case pc=3.2261e-01
#   Baseline pass 4/1000 | t=0.09s | iters=700 | grad_evals=3500 | worst-case pc=3.7190e-01
#   Baseline pass 5/1000 | t=0.11s | iters=875 | grad_evals=4375 | worst-case pc=4.2014e-01
#   Baseline pass 6/1000 | t=0.13s | iters=1050 | grad_evals=5250 | worst-case pc=4.9891e-01
#   Baseline pass 7/1000 | t=0.16s | iters=1225 | grad_evals=6125 | worst-case pc=5.2785e-01
#   Baseline pass 8/1000 | t=0.19s | iters=1400 | grad_evals=7000 | worst-case pc=5.9414e-01
#   Baseline pass 9/1000 | t=0.21s | iters=1575 | grad_evals=7875 | worst-case pc=6.5278e-01
#   Baseline pass 10/1000 | t=0.23s | iters=1750 | grad_evals=8750 | worst-case pc=6.8817e-01
#   Baseline pass 11/1000 | t=0.26s | iters=1925 | grad_evals=9625 | worst-case pc=7.0863e-01
#   Baseline pass 12/1000 | t=0.27s | iters=2000 | grad_evals=10000 | worst-case pc=7.1947e-01
#   Adaptive outer 0/5000 | t=0.00s | bundle=1 | iters=0 | grad_evals=0 | worst-case pc=6.0227e+00
#   Adaptive outer 4/5000 | t=2.02s | bundle=201 | iters=200 | grad_evals=1000 | worst-case pc=1.3249e+00
#   Adaptive outer 8/5000 | t=10.28s | bundle=401 | iters=400 | grad_evals=2000 | worst-case pc=6.4312e-01
#   Adaptive outer 12/5000 | t=21.58s | bundle=601 | iters=600 | grad_evals=3000 | worst-case pc=4.3385e-01
#   Adaptive outer 16/5000 | t=33.38s | bundle=801 | iters=800 | grad_evals=4000 | worst-case pc=3.2066e-01
#   Adaptive outer 20/5000 | t=46.03s | bundle=1001 | iters=1000 | grad_evals=5000 | worst-case pc=2.3595e-01
#   Adaptive outer 24/5000 | t=60.47s | bundle=1201 | iters=1200 | grad_evals=6000 | worst-case pc=1.8005e-01
#   Adaptive outer 28/5000 | t=75.56s | bundle=1401 | iters=1400 | grad_evals=7000 | worst-case pc=1.4348e-01
#   Adaptive outer 32/5000 | t=91.05s | bundle=1601 | iters=1600 | grad_evals=8000 | worst-case pc=1.4403e-01
#   Adaptive outer 36/5000 | t=108.94s | bundle=1801 | iters=1800 | grad_evals=9000 | worst-case pc=1.4403e-01
#   Adaptive outer 40/5000 | t=126.53s | bundle=2001 | iters=2000 | grad_evals=10000 | worst-case pc=1.1228e-01
#
# Plateau summary
#   Method            Found   Onset gradients   Onset CPU   Plateau GN*
#   Baseline          yes               1,750       0.04s   5.2785e-01
#   IPOPT Adaptive    no                    -           -   -

# %%
baseline = results["plateaus"]["baseline"]
adaptive = results["plateaus"]["ipopt_adaptive"]

print("Baseline:", baseline)
print("Adaptive:", adaptive)

if baseline["found"] and adaptive["found"]:
    ratio = baseline["plateau_level"] / adaptive["plateau_level"]
    print("Baseline / Adaptive =", ratio)
    print("目标现象成立:", ratio > 1.0)

print("Gradient-evaluation plot:",
      results["plots"]["baseline_vs_ipopt_gradient_evaluations"])
print("CPU-time plot:",
      results["plots"]["baseline_vs_ipopt_cpu_time"])
# Out:
# Baseline: {'found': True, 'onset_index': 2, 'onset_grad_evals': 1750, 'onset_cpu_time': 0.04276013374328613, 'plateau_level': 0.5278525445896954}
# Adaptive: {'found': False, 'onset_index': None, 'onset_grad_evals': None, 'onset_cpu_time': None, 'plateau_level': None}
# Gradient-evaluation plot: /Users/shirch/vscode101/.venv/First-order-method-smooth-MOO/Adaptive Bundle Algorithm/output/plateau result/K5/baseline_vs_ipopt_gradient_evaluations_001.png
# CPU-time plot: /Users/shirch/vscode101/.venv/First-order-method-smooth-MOO/Adaptive Bundle Algorithm/output/plateau result/K5/baseline_vs_ipopt_cpu_time_001.png
