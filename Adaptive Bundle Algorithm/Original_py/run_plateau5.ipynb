# %%
from experiments import experiment_mlp_plateau_comparison

# %%
cases = [
    dict(K=5, p=5, n=25, h=4, max_grad_evals=200000,
         adaptive_eval_every_n_grads=1000),

    dict(K=6, p=6, n=30, h=2, max_grad_evals=18_000,
         adaptive_eval_every_n_grads=1500),

    dict(K=7, p=7, n=35, h=2, max_grad_evals=32_000,
         adaptive_eval_every_n_grads=2800),

    dict(K=8, p=8, n=40, h=2, max_grad_evals=50_000,
         adaptive_eval_every_n_grads=4800),
]

# %%
# 建议一次先运行一组
case = cases[0]

results = experiment_mlp_plateau_comparison(
    verbose=True,

    seed=10,
    init_seed=11,

    coarse_resolution=9,
    n_passes=1000,
    steps_per_point_per_pass=5,
    baseline_eval_every_n_grads=1000,

    max_outer=5000,
    max_inner=50,
    lambda_max_starts=20,
    prune_inner=False,

    plateau_window=5,
    plateau_relative_improvement_tol=0.05,
    plateau_consecutive_windows=2,

    output_dir=(
        "/Users/shirch/vscode101/.venv/First-order-method-smooth-MOO/"
        "Adaptive Bundle Algorithm/output/plateau result/"
        f"K{case['K']}"
    ),

    **case,
)
# Out:
# ========================================================================
# Plateau comparison — baseline vs IPOPT adaptive
# ========================================================================
#   Shared problem: K=5, p=5, n=25, hidden_sizes=[4], backend=torch, d=49, max_grad_evals=200000, init_seed=11
#   Baseline pass 0/1000 | t=0.00s | iters=0 | grad_evals=0 | worst-case pc=2.4357e+01
#   Baseline pass 1/1000, point 40/715 | t=0.25s | iters=200 | grad_evals=1000 | worst-case pc=1.8141e+01
#   Baseline pass 1/1000, point 80/715 | t=0.50s | iters=400 | grad_evals=2000 | worst-case pc=4.5735e+00
#   Baseline pass 1/1000, point 120/715 | t=0.75s | iters=600 | grad_evals=3000 | worst-case pc=4.5735e+00
#   Baseline pass 1/1000, point 160/715 | t=1.05s | iters=800 | grad_evals=4000 | worst-case pc=4.5735e+00
#   Baseline pass 1/1000, point 200/715 | t=1.30s | iters=1000 | grad_evals=5000 | worst-case pc=4.5735e+00
#   Baseline pass 1/1000, point 240/715 | t=1.55s | iters=1200 | grad_evals=6000 | worst-case pc=2.2154e+00
#   Baseline pass 1/1000, point 280/715 | t=1.82s | iters=1400 | grad_evals=7000 | worst-case pc=1.6515e+00
#   Baseline pass 1/1000, point 320/715 | t=2.07s | iters=1600 | grad_evals=8000 | worst-case pc=1.2214e+00
#   Baseline pass 1/1000, point 360/715 | t=2.35s | iters=1800 | grad_evals=9000 | worst-case pc=8.9788e-01
#   Baseline pass 1/1000, point 400/715 | t=2.59s | iters=2000 | grad_evals=10000 | worst-case pc=3.1156e-01
#   Baseline pass 1/1000, point 440/715 | t=2.83s | iters=2200 | grad_evals=11000 | worst-case pc=1.9810e-01
#   Baseline pass 1/1000, point 480/715 | t=3.12s | iters=2400 | grad_evals=12000 | worst-case pc=1.1387e-01
#   Baseline pass 1/1000, point 520/715 | t=3.36s | iters=2600 | grad_evals=13000 | worst-case pc=6.1367e-02
#   Baseline pass 1/1000, point 560/715 | t=3.60s | iters=2800 | grad_evals=14000 | worst-case pc=5.6106e-02
#   Baseline pass 1/1000, point 600/715 | t=3.88s | iters=3000 | grad_evals=15000 | worst-case pc=5.6106e-02
#   Baseline pass 1/1000, point 640/715 | t=4.15s | iters=3200 | grad_evals=16000 | worst-case pc=5.6106e-02
#   Baseline pass 1/1000, point 680/715 | t=4.39s | iters=3400 | grad_evals=17000 | worst-case pc=5.6106e-02
#   Baseline pass 2/1000, point 5/715 | t=4.62s | iters=3600 | grad_evals=18000 | worst-case pc=5.6106e-02
#   Baseline pass 2/1000, point 45/715 | t=4.87s | iters=3800 | grad_evals=19000 | worst-case pc=5.6106e-02
#   Baseline pass 2/1000, point 85/715 | t=5.13s | iters=4000 | grad_evals=20000 | worst-case pc=5.6106e-02
#   Baseline pass 2/1000, point 125/715 | t=5.37s | iters=4200 | grad_evals=21000 | worst-case pc=5.5467e-02
#   Baseline pass 2/1000, point 165/715 | t=5.65s | iters=4400 | grad_evals=22000 | worst-case pc=5.5467e-02
#   Baseline pass 2/1000, point 205/715 | t=5.97s | iters=4600 | grad_evals=23000 | worst-case pc=5.5478e-02
#   Baseline pass 2/1000, point 245/715 | t=6.28s | iters=4800 | grad_evals=24000 | worst-case pc=5.5478e-02
#   Baseline pass 2/1000, point 285/715 | t=6.56s | iters=5000 | grad_evals=25000 | worst-case pc=5.5478e-02
#   Baseline pass 2/1000, point 325/715 | t=6.88s | iters=5200 | grad_evals=26000 | worst-case pc=5.2168e-02
#   Baseline pass 2/1000, point 365/715 | t=7.21s | iters=5400 | grad_evals=27000 | worst-case pc=5.0190e-02
#   Baseline pass 2/1000, point 405/715 | t=7.55s | iters=5600 | grad_evals=28000 | worst-case pc=5.0190e-02
#   Baseline pass 2/1000, point 445/715 | t=7.83s | iters=5800 | grad_evals=29000 | worst-case pc=5.0190e-02

# %%
baseline = results["plateaus"]["baseline"]
adaptive = results["plateaus"]["ipopt_adaptive"]

print("Baseline:", baseline)
print("Adaptive:", adaptive)

if baseline["found"] and adaptive["found"]:
    ratio = baseline["plateau_level"] / adaptive["plateau_level"]
    print("Baseline / Adaptive =", ratio)
    print("目标现象成立:", ratio > 1.0)

print("Gradient-evaluation plot:",
      results["plots"]["baseline_vs_ipopt_gradient_evaluations"])
print("CPU-time plot:",
      results["plots"]["baseline_vs_ipopt_cpu_time"])
# Out:
# Baseline: {'found': False, 'onset_index': None, 'onset_grad_evals': None, 'onset_cpu_time': None, 'plateau_level': None}
# Adaptive: {'found': False, 'onset_index': None, 'onset_grad_evals': None, 'onset_cpu_time': None, 'plateau_level': None}
# Gradient-evaluation plot: /Users/shirch/vscode101/.venv/First-order-method-smooth-MOO/Adaptive Bundle Algorithm/output/plateau result/K5/baseline_vs_ipopt_gradient_evaluations_001.png
# CPU-time plot: /Users/shirch/vscode101/.venv/First-order-method-smooth-MOO/Adaptive Bundle Algorithm/output/plateau result/K5/baseline_vs_ipopt_cpu_time_001.png
