# %%
from experiments import experiment_mlp_plateau_comparison

# %%
cases = [
    dict(K=5, p=5, n=25, h=2, max_grad_evals=10_000,
         adaptive_eval_every_n_grads=1000),

    dict(K=6, p=6, n=30, h=2, max_grad_evals=18_000,
         adaptive_eval_every_n_grads=1500),

    dict(K=7, p=7, n=35, h=2, max_grad_evals=32_000,
         adaptive_eval_every_n_grads=2800),

    dict(K=8, p=8, n=40, h=2, max_grad_evals=50_000,
         adaptive_eval_every_n_grads=4800),
]

# %%
# 建议一次先运行一组
case = cases[1]

results = experiment_mlp_plateau_comparison(
    verbose=True,

    seed=10,
    init_seed=11,

    coarse_resolution=3,
    n_passes=1000,
    steps_per_point_per_pass=5,
    baseline_eval_every_n_grads=None,

    max_outer=5000,
    max_inner=50,
    lambda_max_starts=20,
    prune_inner=False,

    plateau_window=5,
    plateau_relative_improvement_tol=0.05,
    plateau_consecutive_windows=2,

    output_dir=(
        "/Users/shirch/vscode101/.venv/First-order-method-smooth-MOO/"
        "Adaptive Bundle Algorithm/output/plateau result/"
        f"K{case['K']}"
    ),

    **case,
)
# Out:
# ========================================================================
# Plateau comparison — baseline vs IPOPT adaptive
# ========================================================================
#   Shared problem: K=6, p=6, n=30, h=2, d=32, max_grad_evals=18000, init_seed=11
#   Baseline pass 0/1000 | t=0.00s | iters=0 | grad_evals=0 | worst-case pc=7.6935e+00
#   Baseline pass 1/1000 | t=0.05s | iters=280 | grad_evals=1680 | worst-case pc=3.2639e-01
#   Baseline pass 2/1000 | t=0.09s | iters=560 | grad_evals=3360 | worst-case pc=2.8823e-01
#   Baseline pass 3/1000 | t=0.13s | iters=840 | grad_evals=5040 | worst-case pc=3.1661e-01
#   Baseline pass 4/1000 | t=0.17s | iters=1120 | grad_evals=6720 | worst-case pc=4.0810e-01
#   Baseline pass 5/1000 | t=0.20s | iters=1400 | grad_evals=8400 | worst-case pc=4.1174e-01
#   Baseline pass 6/1000 | t=0.24s | iters=1680 | grad_evals=10080 | worst-case pc=5.0369e-01
#   Baseline pass 7/1000 | t=0.28s | iters=1960 | grad_evals=11760 | worst-case pc=5.2744e-01
#   Baseline pass 8/1000 | t=0.32s | iters=2240 | grad_evals=13440 | worst-case pc=5.5673e-01
#   Baseline pass 9/1000 | t=0.38s | iters=2520 | grad_evals=15120 | worst-case pc=5.6441e-01
#   Baseline pass 10/1000 | t=0.42s | iters=2800 | grad_evals=16800 | worst-case pc=5.9396e-01
#   Baseline pass 11/1000 | t=0.45s | iters=3000 | grad_evals=18000 | worst-case pc=5.7103e-01
#   Adaptive outer 0/5000 | t=0.00s | bundle=1 | iters=0 | grad_evals=0 | worst-case pc=7.6935e+00
#   Adaptive outer 5/5000 | t=2.92s | bundle=251 | iters=250 | grad_evals=1500 | worst-case pc=1.0671e+00
#   Adaptive outer 10/5000 | t=17.35s | bundle=501 | iters=500 | grad_evals=3000 | worst-case pc=5.4143e-01
#   Adaptive outer 15/5000 | t=32.79s | bundle=751 | iters=750 | grad_evals=4500 | worst-case pc=4.2028e-01
#   Adaptive outer 20/5000 | t=49.82s | bundle=1001 | iters=1000 | grad_evals=6000 | worst-case pc=3.4168e-01
#   Adaptive outer 25/5000 | t=69.49s | bundle=1251 | iters=1250 | grad_evals=7500 | worst-case pc=2.9985e-01
#   Adaptive outer 30/5000 | t=88.31s | bundle=1501 | iters=1500 | grad_evals=9000 | worst-case pc=2.4000e-01
#   Adaptive outer 35/5000 | t=110.44s | bundle=1751 | iters=1750 | grad_evals=10500 | worst-case pc=2.8119e-01
#   Adaptive outer 40/5000 | t=133.63s | bundle=2001 | iters=2000 | grad_evals=12000 | worst-case pc=2.0134e-01
#   Adaptive outer 45/5000 | t=157.34s | bundle=2251 | iters=2250 | grad_evals=13500 | worst-case pc=1.8534e-01
#   Adaptive outer 50/5000 | t=183.42s | bundle=2501 | iters=2500 | grad_evals=15000 | worst-case pc=1.7100e-01
#   Adaptive outer 55/5000 | t=212.72s | bundle=2751 | iters=2750 | grad_evals=16500 | worst-case pc=1.4989e-01
#   Adaptive outer 60/5000 | t=245.94s | bundle=3001 | iters=3000 | grad_evals=18000 | worst-case pc=1.5380e-01
#
# Plateau summary
#   Method            Found   Onset gradients   Onset CPU   Plateau GN*
#   Baseline          yes               3,360       0.09s   5.1557e-01
#   IPOPT Adaptive    no                    -           -   -

# %%
baseline = results["plateaus"]["baseline"]
adaptive = results["plateaus"]["ipopt_adaptive"]

print("Baseline:", baseline)
print("Adaptive:", adaptive)

if baseline["found"] and adaptive["found"]:
    ratio = baseline["plateau_level"] / adaptive["plateau_level"]
    print("Baseline / Adaptive =", ratio)
    print("目标现象成立:", ratio > 1.0)

print("Gradient-evaluation plot:",
      results["plots"]["baseline_vs_ipopt_gradient_evaluations"])
print("CPU-time plot:",
      results["plots"]["baseline_vs_ipopt_cpu_time"])
# Out:
# Baseline: {'found': True, 'onset_index': 2, 'onset_grad_evals': 1750, 'onset_cpu_time': 0.04549860954284668, 'plateau_level': 0.5278525445896954}
# Adaptive: {'found': False, 'onset_index': None, 'onset_grad_evals': None, 'onset_cpu_time': None, 'plateau_level': None}
